# %% [markdown]
# # 08b — Low-level interface with `dask.delayed`
#
# Wrap custom functions so they play nicely with Dask's lazy task graphs.

# %%
import dask
import dask.array as da
import numpy as np

# %%
@dask.delayed
def doubled(x):
    return x * 2

# %%
# Use with a NumPy array (small example)
a = np.arange(12).reshape(3,4)
d = doubled(a)
# still lazy
d

# %%
# compute materializes the result
res = d.compute(); res

# %% [markdown]
# ## Build a small delayed graph (add/multiply)

# %%
@dask.delayed
def add(x, y):
    return x + y

@dask.delayed
def mul(x, y):
    return x * y

x = add(1, 2)
y = mul(x, 10)
z = add(y, 5)

try:
    z.visualize(filename='delayed_chain.svg')
    print('Saved graph to delayed_chain.svg')
except Exception as e:
    print('Visualization skipped:', e)

z.compute()
