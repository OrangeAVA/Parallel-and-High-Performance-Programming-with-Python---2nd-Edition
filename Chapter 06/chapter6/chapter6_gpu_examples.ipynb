# %% [markdown]
# # Chapter 6 – GPU Programming with Python
# Examples for Numba (CUDA) and PyOpenCL. Make sure your drivers are installed.
# **Tip:** set `PYOPENCL_CTX=0` to skip platform prompts.

# %%
# Numba CUDA sanity check: increment a 1D array
# %run numba_add_one_1d.py

# %%
# PyOpenCL: list platforms/devices
# %run opencl_list_platforms.py

# %%
# Numba: coalesced vs non-coalesced memory access
# %run numba_coalesced_vs_noncoalesced.py

# %%
# PyOpenCL: elementwise kernel
# %run opencl_elementwise.py
